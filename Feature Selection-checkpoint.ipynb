# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# %%
data= pd.read_csv("Project sample/IRIS.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### DATA CLEANING

# %%
df =data.copy()

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
#
df.drop_duplicates(inplace = True)

# %% [markdown]
# ### FEATURE ENGINEERING

# %%
## Map species to numerical values
df['species'] =df['species'].astype('category').cat.codes
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, vars=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])# Selecting specific variables

# %%
sns.pairplot(df, hue='species', palette='coolwarm') # Using a different color palette or grouping by a categorical variable

# %%
sns.pairplot(df, kind='reg')  # Adds regression lines to the scatter plots

# %%
sns.pairplot(df, diag_kind='kde', markers=["o", "s", "D"], hue='species') # Adding additional options

# %%
corr=df.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.109321      0.871305     0.817058  0.782904
# sepal_width      -0.109321     1.000000     -0.421057    -0.356376 -0.418348
# petal_length      0.871305    -0.421057      1.000000     0.961883  0.948339
# petal_width       0.817058    -0.356376      0.961883     1.000000  0.955693
# species           0.782904    -0.418348      0.948339     0.955693  1.000000

# %%
sns.heatmap(corr, annot=True,cmap='BuPu')
plt.title("Heatmap of correlated matrices")
plt.show()

# %%
from sklearn.model_selection import train_test_split, cross_val_score
#features and target variable
x= df.drop('species',axis=1)
y=df['species']
# split the dataset into training and testing sets
x_train, x_test, y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# ## Logistic Regresion

# %%
print

# %%
# import the logistic Regression class from sklearn
from sklearn.linear_model import LogisticRegression
# initialize the Logistic Regression model
Logistic_model = LogisticRegression()
# fit the model to the training data (x_train and y_train)
Logistic_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Validate Logistic Regression

# %%
#predict the target variable for the test data(x_test)
y_pred_logistic=Logistic_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print("Logistic Regression Results:")
print("Accuracy:",accuracy_score(y_test,y_pred_logistic))
# Out:
# Logistic Regression Results:
# Accuracy: 0.9333333333333333

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
x=df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y= df['species']  
# split the dataset into training and testing sets
x_train, x_test, y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
# initialize the Logistic Regression model
Logistic_model = LogisticRegression()
# fit the model to the training data (x_train and y_train)
Logistic_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#predict the target variable for the test data(x_test)
y_pred_logistic=Logistic_model.predict(x_test)

# %%
print("Logistic Regression Results:")
print("Accuracy:",accuracy_score(y_test,y_pred_logistic))
# Out:
# Logistic Regression Results:
# Accuracy: 0.9333333333333333

# %%
plt.scatter(y_test, y_pred_logistic,color='cyan')
plt.title('scatter of Actual Values and predicted values ')
plt.xlabel('y_test')
plt.ylabel('y_pred_logistic')
plt.grid(True)
plt.show()

# %%
plt.bar(y_test, y_pred_logistic,color='cyan')
plt.title('A bar chart of Actual Values and predicted values ')
plt.xlabel('y_test')
plt.ylabel('y_pred_logistic')
plt.grid(True)
plt.show()

# %%
plt.plot(y_test, y_pred_logistic,color='cyan')
plt.title('A plot of Actual Values and predicted values ')
plt.xlabel('y_test')
plt.ylabel('y_pred_logistic')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(2,2))
plt.pie(y_test, y_pred_logistic)
plt.title('A pie chart of the actual values verses Predicted Values')
plt.show()

# %%
y_pred_logistic
# Out:
# array([2, 1, 2, 0, 1, 0, 1, 0, 2, 0, 0, 1, 2, 1, 2, 1, 0, 1, 1, 0, 0, 2,
#        0, 2, 1, 0, 1, 2, 1, 0, 2, 0, 2, 0, 0, 2, 2, 2, 0, 0, 0, 2, 1, 2,
#        1], dtype=int8)

# %%
y_test
# Out:
# 127    2
# 53     1
# 140    2
# 19     0
# 106    2
# 12     0
# 78     1
# 31     0
# 83     1
# 9      0
# 26     0
# 98     1
# 146    2
# 69     1
# 136    2
# 68     1
# 18     0
# 71     1
# 126    2
# 30     0
# 29     0
# 107    2
# 38     0
# 120    2
# 57     1
# 22     0
# 66     1
# 135    2
# 84     1
# 11     0
# 137    2
# 47     0
# 121    2
# 27     0
# 4      0
# 129    2
# 131    2
# 148    2
# 44     0
# 16     0
# 10     0
# 117    2
# 87     1
# 141    2
# 58     1
# Name: species, dtype: int8

# %% [markdown]
# ### RANDOM FOREST

# %%
from sklearn.model_selection import train_test_split, cross_val_score
#features and target variable
x= df.drop('species',axis=1)
y=df['species']
# split the dataset into training and testing sets
x_train, x_test, y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rm=RandomForestClassifier()
rm.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### VALIDATION OF RM

# %%
rm_pred=rm.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print("Random Forest Accuracy is:")
print("Accuracy:",accuracy_score(y_test,rm_pred))
# Out:
# Random Forest Accuracy is:
# Accuracy: 0.9555555555555556

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
#features and target variable
x= df.drop('species',axis=1)
y=df['species']
# split the dataset into training and testing sets
x_train, x_test, y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### VALIDATION OF KNN

# %%
knn_pred=knn.predict(x_test)

# %%
print("KNN Accuracy is:")
print("Accuracy:",accuracy_score(y_test,knn_pred))
# Out:
# KNN Accuracy is:
# Accuracy: 0.9555555555555556

# %%
print("K-Neighbors Classifier Accuracy is:")
print("Accuracy:", accuracy_score(y_test, knn_pred))
print("Classification Report:\n", classification_report(y_test, knn_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, knn_pred))
# Out:
# K-Neighbors Classifier Accuracy is:
# Accuracy: 0.9555555555555556
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.92      0.92      0.92        12
#            2       0.94      0.94      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45
#
# Confusion Matrix:
#  [[17  0  0]
#  [ 0 11  1]
#  [ 0  1 15]]

# %% [markdown]
# ### SVM

# %%
#from sklearn.ensemble import KNeighborsClassifier
#from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
#features and target variable
x= df.drop('species',axis=1)
y=df['species']
# split the dataset into training and testing sets
x_train, x_test, y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
sv=SVC()
sv.fit(x_train, y_train)
# Out:
# SVC()

# %%
sv_pred=sv.predict(x_test)

# %%
sv_accuracy =accuracy_score(y_test,sv_pred)

# %%
sv_accuracy
# Out:
# 0.9555555555555556

# %%
p_wi=4.5
s_width=5.7
p_len
s_len
# how to pass this parameters to a model to make prediction
#how to save the model to a csv/xlsx
# Go check how to embedd models

# %%
#flask
# pipeline
